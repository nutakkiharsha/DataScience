# %%
                                                    SKILL-3
                                                                                                                190031994
                                                                                                                N.Harsha Vardhan

# %%
import pandas as pd
import numpy as np

# %%
#loading data
hospital_ratings = pd.read_csv('Hospital General Information.csv',encoding="ISO-8859-1")

# %%
hospital_ratings
# Out:
#       Provider ID                     Hospital Name  \
# 0           10001  SOUTHEAST ALABAMA MEDICAL CENTER
# 1           10005     MARSHALL MEDICAL CENTER SOUTH
# 2           10006    ELIZA COFFEE MEMORIAL HOSPITAL
# 3           10007          MIZELL MEMORIAL HOSPITAL
# 4           10008       CRENSHAW COMMUNITY HOSPITAL
# ...           ...                               ...
# 4807       670118              FIRST TEXAS HOSPITAL
# 4808       640001       LBJ TROPICAL MEDICAL CENTER
# 4809       650001  GUAM MEMORIAL HOSPITAL AUTHORITY
# 4810       650003        GUAM REGIONAL MEDICAL CITY
# 4811       660001        COMMONWEALTH HEALTH CENTER
#
#                             Address       City State  ZIP Code County Name  \
# 0            1108 ROSS CLARK CIRCLE     DOTHAN    AL     36301     HOUSTON
# 1        2505 U S HIGHWAY 431 NORTH       BOAZ    AL     35957    MARSHALL
# 2                205 MARENGO STREET   FLORENCE    AL     35631  LAUDERDALE
# ...

# %%
#cleaning
hospital_ratings.isnull()
# Out:
#       Provider ID  Hospital Name  Address   City  State  ZIP Code  \
# 0           False          False    False  False  False     False
# 1           False          False    False  False  False     False
# 2           False          False    False  False  False     False
# 3           False          False    False  False  False     False
# 4           False          False    False  False  False     False
# ...           ...            ...      ...    ...    ...       ...
# 4807        False          False    False  False  False     False
# 4808        False          False    False  False  False     False
# 4809        False          False    False  False  False     False
# 4810        False          False    False  False  False     False
# 4811        False          False    False  False  False     False
#
#       County Name  Phone Number  Hospital Type  Hospital Ownership  ...  \
# 0           False         False          False               False  ...
# ...

# %%
hospital_ratings.isnull().sum()
# Out:
# Provider ID                                                         0
# Hospital Name                                                       0
# Address                                                             0
# City                                                                0
# State                                                               0
# ZIP Code                                                            0
# County Name                                                        15
# Phone Number                                                        0
# Hospital Type                                                       0
# Hospital Ownership                                                  0
# Emergency Services                                                  0
# Meets criteria for meaningful use of EHRs                         143
# Hospital overall rating                                             0
# ...

# %%
hospital_ratings.notnull()
# Out:
#       Provider ID  Hospital Name  Address  City  State  ZIP Code  County Name  \
# 0            True           True     True  True   True      True         True
# 1            True           True     True  True   True      True         True
# 2            True           True     True  True   True      True         True
# 3            True           True     True  True   True      True         True
# 4            True           True     True  True   True      True         True
# ...           ...            ...      ...   ...    ...       ...          ...
# 4807         True           True     True  True   True      True         True
# 4808         True           True     True  True   True      True        False
# 4809         True           True     True  True   True      True        False
# 4810         True           True     True  True   True      True        False
# 4811         True           True     True  True   True      True        False
#
# ...

# %%
#hospital analysis - "hospital type by ownership"
dff=hospital_ratings.groupby(['Hospital Ownership','Hospital Type']).size()
dff
# Out:
# Hospital Ownership                           Hospital Type
# Government - Federal                         Acute Care Hospitals           37
#                                              Critical Access Hospitals       8
# Government - Hospital District or Authority  Acute Care Hospitals          273
#                                              Childrens                       1
#                                              Critical Access Hospitals     287
# Government - Local                           Acute Care Hospitals          176
#                                              Critical Access Hospitals     231
# Government - State                           Acute Care Hospitals           50
#                                              Childrens                       3
#                                              Critical Access Hospitals      12
# Physician                                    Acute Care Hospitals           65
# ...

# %%
#Total number of hospitals in eack state
df2=hospital_ratings.groupby(['State']).size()
df2
# Out:
# State
# AK     22
# AL     90
# AR     75
# AS      1
# AZ     80
# CA    343
# CO     78
# CT     31
# DC      8
# DE      7
# FL    187
# GA    133
# GU      2
# HI     23
# IA    116
# ID     41
# IL    180
# IN    120
# KS    137
# KY     94
# LA    121
# MA     64
# MD     49
# ME     33
# MI    131
# MN    131
# MO    112
# MP      1
# MS     95
# MT     62
# NC    107
# ND     44
# NE     89
# NH     26
# NJ     66
# NM     41
# NV     35
# NY    171
# OH    168
# OK    124
# OR     60
# PA    171
# PR     52
# RI     11
# SC     60
# SD     60
# TN    107
# TX    411
# UT     46
# VA     86
# VI      2
# VT     14
# WA     91
# WI    126
# WV     49
# WY     28
# dtype: int64

# %%
#county wise hospital numbers in 'TX'
df3=hospital_ratings[hospital_ratings['State']=='TX']
df3
# Out:
#       Provider ID                        Hospital Name  \
# 3954       450002         PROVIDENCE MEMORIAL HOSPITAL
# 3955       450007     PETERSON REGIONAL MEDICAL CENTER
# 3956       450010   UNITED REGIONAL HEALTH CARE SYSTEM
# 3957       450011     ST JOSEPH REGIONAL HEALTH CENTER
# 3958       450015  PARKLAND HEALTH AND HOSPITAL SYSTEM
# ...           ...                                  ...
# 4803       670114                WEIMAR MEDICAL CENTER
# 4804       670115         CLEVELAND EMERGENCY HOSPTIAL
# 4805       670116                   WISE HEALTH SYSTEM
# 4806       670117     TEXAS GENERAL HOSPITAL- VZRMC LP
# 4807       670118                 FIRST TEXAS HOSPITAL
#
#                          Address           City State  ZIP Code County Name  \
# 3954            2001 N OREGON ST        EL PASO    TX     79902     EL PASO
# 3955      551 HILL COUNTRY DRIVE      KERRVILLE    TX     78028        KERR
# ...

# %%
#Distribution of 'Hospital Type' and 'ownership on Texas'
distri=hospital_ratings[['State','Hospital Ownership']]
distri1 = distri[hospital_ratings['State']=='TX']
distri1
# Out:
#      State                           Hospital Ownership
# 3954    TX                                  Proprietary
# 3955    TX               Voluntary non-profit - Private
# 3956    TX               Voluntary non-profit - Private
# 3957    TX               Voluntary non-profit - Private
# 3958    TX  Government - Hospital District or Authority
# ...    ...                                          ...
# 4803    TX                                  Proprietary
# 4804    TX                                  Proprietary
# 4805    TX  Government - Hospital District or Authority
# 4806    TX                                  Proprietary
# 4807    TX                                  Proprietary
#
# [411 rows x 2 columns]

# %%
#timeliness of care national comparision footnote and its hospital
time=pd.crosstab(hospital_ratings['Hospital Name'],hospital_ratings['Timeliness of care national comparison footnote']=='Above the nation average')
time
# Out:
# Timeliness of care national comparison footnote  False
# Hospital Name
# ABBEVILLE AREA MEDICAL CENTER                        1
# ABBEVILLE GENERAL HOSPITAL                           1
# ABBOTT NORTHWESTERN HOSPITAL                         1
# ABILENE REGIONAL MEDICAL CENTER                      1
# ABINGTON MEMORIAL HOSPITAL                           1
# ...                                                ...
# YORK HOSPITAL                                        2
# YUKON KUSKOKWIM DELTA REG HOSPITAL                   1
# YUMA DISTRICT HOSPITAL                               1
# YUMA REGIONAL MEDICAL CENTER                         1
# ZUNI COMPREHENSIVE COMMUNITY HEALTH CENTER           1
#
# [4623 rows x 1 columns]

# %%
#hospital rating
ratings=hospital_ratings[['Hospital Name','Hospital overall rating']]
ratings
# Out:
#                          Hospital Name Hospital overall rating
# 0     SOUTHEAST ALABAMA MEDICAL CENTER                       3
# 1        MARSHALL MEDICAL CENTER SOUTH                       3
# 2       ELIZA COFFEE MEMORIAL HOSPITAL                       2
# 3             MIZELL MEMORIAL HOSPITAL                       2
# 4          CRENSHAW COMMUNITY HOSPITAL                       3
# ...                                ...                     ...
# 4807              FIRST TEXAS HOSPITAL           Not Available
# 4808       LBJ TROPICAL MEDICAL CENTER           Not Available
# 4809  GUAM MEMORIAL HOSPITAL AUTHORITY                       3
# 4810        GUAM REGIONAL MEDICAL CITY           Not Available
# 4811        COMMONWEALTH HEALTH CENTER           Not Available
#
# [4812 rows x 2 columns]

# %%
#Find Acute hospitals with rating(4) along with state
Acute=hospital_ratings.loc[(hospital_ratings["Hospital Type"]=="Acute CareHospitals")&(hospital_ratings["Hospital overall rating"]=="3"),["State"]]
Acute
# Out:
# Empty DataFrame
# Columns: [State]
# Index: []

# %%
#which hospital has highest non availability of safety of care dada
safety=hospital_ratings[['Hospital Name','Safety of care national comparison']]
safety1=safety[hospital_ratings['Safety of care national comparison']=='Not Available']
safety1
# Out:
#                          Hospital Name Safety of care national comparison
# 3             MIZELL MEMORIAL HOSPITAL                      Not Available
# 4          CRENSHAW COMMUNITY HOSPITAL                      Not Available
# 8                CALLAHAN EYE HOSPITAL                      Not Available
# 11             CHEROKEE MEDICAL CENTER                      Not Available
# 15                    WEDOWEE HOSPITAL                      Not Available
# ...                                ...                                ...
# 4807              FIRST TEXAS HOSPITAL                      Not Available
# 4808       LBJ TROPICAL MEDICAL CENTER                      Not Available
# 4809  GUAM MEMORIAL HOSPITAL AUTHORITY                      Not Available
# 4810        GUAM REGIONAL MEDICAL CITY                      Not Available
# 4811        COMMONWEALTH HEALTH CENTER                      Not Available
#
# [2168 rows x 2 columns]

# %%
#different types of patient experience national comparision and their list their provider id
experience=hospital_ratings[['Patient experience national comparison','Provider ID']]
experience
# Out:
#      Patient experience national comparison  Provider ID
# 0                Below the national average        10001
# 1              Same as the national average        10005
# 2                Below the national average        10006
# 3              Same as the national average        10007
# 4                             Not Available        10008
# ...                                     ...          ...
# 4807                          Not Available       670118
# 4808                          Not Available       640001
# 4809                          Not Available       650001
# 4810                          Not Available       650003
# 4811                          Not Available       660001
#
# [4812 rows x 2 columns]

# %%
nonsafety=hospital_ratings.groupby('Hospital Type')['Safety of care national comparison'].count()
nonsafety
# Out:
# Hospital Type
# Acute Care Hospitals         3369
# Childrens                      99
# Critical Access Hospitals    1344
# Name: Safety of care national comparison, dtype: int64

# %%
df5=hospital_ratings.groupby('Safety of care national comparison')[['Provider ID']].count()
df5
# Out:
#                                     Provider ID
# Safety of care national comparison
# Above the national average                  786
# Below the national average                  664
# Not Available                              2168
# Same as the national average               1194
